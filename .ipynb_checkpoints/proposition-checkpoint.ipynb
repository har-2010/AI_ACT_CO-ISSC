# %%
# %%capture
from __future__ import annotations

# To reload modules on update without restarting the kernel
# %load_ext autoreload
# %autoreload 2

from helpers import Corpus, Model
from sentence_transformers import SentenceTransformer

# %%
core_concepts = {
    "artificial intelligence" : {
        "ai domain" : {},
        "ai system" : {
            "no risk ai system" : {},
            "high risk ai system" : {},
            "low risk ai system" : {},
            
        },
        "ai system development process" : {
            "ai system approach" : {},
            "ai system quality measure" : {},
             "ai system properties" : {},
        },
    },

    "data" : {
        "personal data" : {},
        "pseudo anonymous data" : {},
        "anonymous data" : {},
    },

    "organization or person" : {
        "provider" : {},
        "user" : {
            "affected entity" : {},
        },
        "regulator" : {
            "eu country" : {},
        },
    },

    "risk": {
        "data risk" : {
            "poisoning risk" : {},
        },
        "system risk" : {
            "terrorist attack risk" : {},
        },
        "risk management" : {},
    },

    "law": {
        "regulation": {
            "right": {},
            "rule": {},
            "requirement": {},
            "obligation": {},
        },
        "law text": {},
        "authority": {},
    },

    "market": {
        "product": {},
        "service": {},
    },

    "other": {},

    "system": {},
}

# %%
import pandas
source = r"..\new term classification.xlsx"
pandas.read_excel(source)[["Concept","Core Concept"]]
# Out:
#                                           Concept Core Concept
# 0                                              AI   AnythingAI
# 1                                    high-risk ai   AnythingAI
# 2                        experimentation facility   AnythingAI
# 3                             applicable function   AnythingAI
# 4                      data access infrastructure   AnythingAI
# ..                                            ...          ...
# 898                      medical device framework          Law
# 899                            timely enforcement          Law
# 900                                 lex specialis          Law
# 901  artificial intelligence regulatory sandboxe           Law
# 902                                    definition        Other
#
# [903 rows x 2 columns]

# %%
pandas.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vTSsp1oV819VYKVBC8JV3Cbsat2Q9iEL0Zh_-RMIRgrP3eR9RkWLceBVrzlBrEPlZ9sMnBROvKWo8Hm/pub?gid=0&single=true&output=csv")
# Out:
#                            Concept  Fréquence             Core Concept  \
# 0                medical condition        1.0  Artificial intelligence
# 1    artificial intelligence field        1.0  Artificial intelligence
# 2                  aviation safety        1.0  Artificial intelligence
# 3         biometric identification        1.0  Artificial intelligence
# 4                   border control        4.0  Artificial intelligence
# ..                             ...        ...                      ...
# 914              cross-border user        1.0   Organization or Person
# 915                       employee        1.0   Organization or Person
# 916                   legal person       12.0   Organization or Person
# 917           religious minorities        1.0   Organization or Person
# 918           vulnerable road user        1.0   Organization or Person
#
#        General Core Concept   MH Patricia              Margo  Unnamed: 7  \
# 0                       NaN  NaN      NaN  C'est du contexte         NaN
# 1                       NaN  NaN      NaN                NaN         NaN
# 2                       NaN  NaN      NaN                NaN         NaN
# 3                       NaN  NaN      NaN                NaN         NaN
# 4                       NaN  NaN      NaN                NaN         NaN
# ..                      ...  ...      ...                ...         ...
# 914  Organization or Person  NaN      NaN                NaN         NaN
# 915  Organization or Person  NaN      NaN                NaN         NaN
# 916  Organization or Person  NaN      NaN                NaN         NaN
# 917  Organization or Person  NaN      NaN                NaN         NaN
# 918                     NaN  NaN     user                NaN         NaN
#
#      Unnamed: 8               Unnamed: 9  Unnamed: 10             Unnamed: 11  \
# 0           NaN             Core Concept          NaN                     NaN
# 1           NaN  Artificial intelligence        202.0                 AnyRisk
# 2           NaN                     Data         58.0                 AnyData
# 3           NaN                      Law        261.0  Organization or Person
# 4           NaN   Organization or Person        113.0                 AnyRisk
# ..          ...                      ...          ...                     ...
# 914         NaN                      NaN          NaN                     NaN
# 915         NaN                      NaN          NaN                     NaN
# 916         NaN                      NaN          NaN                     NaN
# 917         NaN                      NaN          NaN                     NaN
# 918         NaN                      NaN          NaN                     NaN
#
#      Unnamed: 12
# 0            NaN
# 1           40.0
# 2           58.0
# 3          113.0
# 4          119.0
# ..           ...
# 914          NaN
# 915          NaN
# 916          NaN
# 917          NaN
# 918          NaN
#
# [919 rows x 13 columns]

# %%
# Corpus based around top level core concepts
corpus = Corpus(
    source="https://docs.google.com/spreadsheets/d/e/2PACX-1vTSsp1oV819VYKVBC8JV3Cbsat2Q9iEL0Zh_-RMIRgrP3eR9RkWLceBVrzlBrEPlZ9sMnBROvKWo8Hm/pub?gid=0&single=true&output=csv",
#     source = r"..\new term classification.xlsx",
    core_concepts = core_concepts
)
# corpus = Corpus()
# Out:
# num 0
# 0
# ['artificial intelligence', 'ai domain', 'ai system', 'no risk ai system', 'high risk ai system', 'low risk ai system', 'ai system development process', 'ai system approach', 'ai system quality measure', 'ai system properties', 'data', 'personal data', 'pseudo anonymous data', 'anonymous data', 'organization or person', 'provider', 'user', 'affected entity', 'regulator', 'eu country', 'risk', 'data risk', 'poisoning risk', 'system risk', 'terrorist attack risk', 'risk management', 'law', 'regulation', 'right', 'rule', 'requirement', 'obligation', 'law text', 'authority', 'market', 'product', 'service', 'other']
# ['artificial intelligence', 'data', 'law', 'organization or person', 'risk', 'market', 'other']

# %%
# corpus.extract_terms_from_pdf("Data/EU.pdf")
corpus.extract_terms_from_onto()
# Out:
# redundant terms:
# 434         cybersecurity
# 557    technical solution
# 897      criminal offence
# Name: Concept, dtype: object
# unique terms:  916

# %%
corpus.extract_hyponyms()

# %%
X, y = corpus.get_training_data()

# %%
model = Model(corpus, min_points=4, dimensions=10, clusterer="c-dbscan", reducer="umap")
# model = Model(corpus, min_points=4, dimensions=10, classifier="svm", reducer="none")

# %%
y_pred = model.iterate(X, y, 5,verbose=1)
# Out:
# -0.064063735
# 288
# cluster size :
# |-artificial intelligence : 68
# |-data : 43
# |-law : 36
# |-organization or person : 69
# |-risk : 21
# |-market : 32
# |-other : 684
#   |-unlabeled terms within 'other': 665
# 0.100655794
# 373
# cluster size :
# |-artificial intelligence : 69
# |-data : 43
# |-law : 36
# |-organization or person : 79
# |-risk : 86
# |-market : 39
# |-other : 601
#   |-unlabeled terms within 'other': 580
# 0.15133059
# 374
# cluster size :
# |-artificial intelligence : 69
# |-data : 43
# |-law : 36
# |-organization or person : 87
# |-risk : 96
# |-market : 39
# |-other : 583
#   |-unlabeled terms within 'other': 579
# 0.13226521
# 392
# cluster size :
# |-artificial intelligence : 69
# |-data : 43
# |-law : 36
# |-organization or person : 91
# |-risk : 96
# |-market : 39
# |-other : 579
#   |-unlabeled terms within 'other': 561
# 0.17068873
# 902
# cluster size :
# |-artificial intelligence : 171
# |-data : 109
# |-law : 170
# |-organization or person : 139
# |-risk : 195
# |-market : 109
# |-other : 60
#   |-unlabeled terms within 'other': 51
# Silhouette : 0.011414412
# Davies Bouldin : 5.564235942189985
# Calinski Harabasz : 10.305154292346218
# False
# size of predicted: 865
# Accuracy : 0.3630057803468208
# Precision : 0.37743379540165795
# Recall : 0.3630057803468208
# f1 : 0.3486657047820387
#                Prediction             Ground truth
# 0                    data                      law
# 1  organization or person   organization or person
# 2                    risk  artificial intelligence
# 3                     law                      law
# 4                     law                      law

# %%
print(y_pred)
