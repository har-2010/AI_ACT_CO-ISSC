# %% [markdown]
# # To run this code for the first time, you need to uncomment and run the code in the following cell.

# %%
# %%capture
# !pip install -r requirements.txt
# import nltk
# nltk.download('stopwords')
# !pip install --upgrade numpy==1.22

# %%
# %%capture
from __future__ import annotations

# To reload modules on update without restarting the kernel
# %load_ext autoreload
# %autoreload 2

from helpers import Corpus, Model
from sentence_transformers import SentenceTransformer

# %%
core_concepts = {
    "artificial intelligence" : {
#         "anything ai" : {
        "ai domain" : {}, 
        "ai system" : { 
            "no risk ai system" : {},
            "high risk ai system" : {},
            "low risk ai system" : {},
            "ai system properties" : {}
            
        },
        "ai system development process" : {
            "ai system approach" : {},
            "ai system quality measure" : {}, 
            
        },
    },

    "data" : {
        "personal data" : {},
        "anonymous data" : {},
    },

    "organization or person" : {
        "provider" : {},
        "user" : {
            "affected entity" : {},
        },
        "regulator" : {
            "eu country" : {},
        },
    },

    "risk": {
        "data risk" : {
            "poisoning risk" : {},
        },
        "system risk" : {
            "terrorist attack risk" : {},
        },
        "risk management" : {},
    },

    "law": {
        "regulation": {
            "right": {},
            "rule": {},
            "requirement": {},
            "obligation": {},
        },
        "law text": {},
        "authority": {},
    },

    "market": {
        "product": {}, # +s when use corpus 1
        "service": {}, # +s
    },

    "other": {},
}

# %% [markdown]
# # Test Function

# %%
# get core ontology of cs corpus
def read_cs_core_ontology(path):
    core_dict = {}
    with open(path,"r") as f:
        lines = f.readlines()   
        i = 0
        while i < len(lines):
            core_concept = lines[i].strip("\n")
            core_dict[core_concept] ={}
            hyponyms = lines[i+1].strip("\n").split(",")[:10] # only use the first ten hyponyms(CC-seeds)
            for hyponym in hyponyms:
                core_dict[core_concept][hyponym] = {}
            i += 2
    core_dict["other"]= {}
    return core_dict


# remove all hyponym relation from core ontology, only keep the core concepts.
def flatten_dict(d):
    """
    flatten dict
    """
    items = {}
    for k, v in d.items():
        if not v=={}:
            items.update(flatten_dict(v).items())
        items[k]={}
#     print(items)
    return dict(items)

# %%
# import csv
# import os
import pandas as pd

def run_and_store_results(clusterer="c-dbscan",
                          reducer="umap",
                          classifier=None,
                          iterations = [1,2,5,10,15],
                          cc_removal=False,
                          dimensions=10,
                          min_points=4,
                          prefix=""):
    """
    test function
    """
    
    results = []
    prediction_df = []
    iterations = iterations
    for iteration in iterations:
        
        print(str(iteration)+" iterations:")
        core_ontology = core_concepts
        
        source = r".\Data\IA Regulation Taxonomy.xlsx"
        corpus = Corpus(
            source=source,
            core_concepts=core_concepts,
        )
        
        corpus.extract_terms_from_onto()
        
        X, y = corpus.get_training_data()
        
        model = Model(corpus, min_points=min_points, dimensions=dimensions, clusterer=clusterer, classifier=classifier,reducer=reducer)

        y_pred = model.iterate(X, y, iteration, verbose=1)

        # result showing 
        
        accuracy = model.accuracy
        precision = model.precision
        recall = model.recall
        f1 = model.f1
        silhouette = model.silhouette_scores[-1] if not len(model.silhouette_scores) == 0 else None
        davies_bouldin = model.davies_bouldin_scores[-1] if not len(model.davies_bouldin_scores) == 0 else None
        calinski_harabasz = model.calinski_harabasz_scores[-1] if not len(model.calinski_harabasz_scores) == 0 else None

        results.append([accuracy, precision, recall, f1,silhouette,davies_bouldin,calinski_harabasz])
        
        prediction_df.append(model.pred_df)
        
        if classifier is not None or clusterer in ["cosine","dbscan"]:
            iterations = iterations[:1]
            break
        
    if classifier==None:
        print()
        print("Summary:")
        df = pd.DataFrame(results,columns=["Accuracy", "Precision", "Recall", "F1", "Silhouette","Davies Bouldin","Calinski Harabasz"])
        df.index = iterations 
        print(df)
    
    
    return prediction_df

# %% [markdown]
# # Corpus：AI Act
# ## All the experimentations of the paper

# %% [markdown]
# ## 1. Default Setting

# %%
df=run_and_store_results(dimensions=10,clusterer="c-dbscan",reducer="umap")
# Out:
# 1 iterations:
# ['artificial intelligence', 'ai domain', 'ai system', 'no risk ai system', 'high risk ai system', 'low risk ai system', 'ai system properties', 'ai system development process', 'ai system approach', 'ai system quality measure', 'data', 'personal data', 'anonymous data', 'organization or person', 'provider', 'user', 'affected entity', 'regulator', 'eu country', 'risk', 'data risk', 'poisoning risk', 'system risk', 'terrorist attack risk', 'risk management', 'law', 'regulation', 'right', 'rule', 'requirement', 'obligation', 'law text', 'authority', 'market', 'product', 'service', 'other']
# ['artificial intelligence', 'data', 'organization or person', 'risk', 'law', 'market', 'other']
# unique terms:  900
# cannot links:21
# must links:30
# 0.09526011
# cluster size :
# |-artificial intelligence : 152
# |-data : 142
# |-organization or person : 168
# |-risk : 144
# |-law : 148
# |-market : 127
# |-other : 55
#   |-unlabeled terms within 'other': 0
# Silhouette : 0.018118415
# Davies Bouldin : 6.169077808826984
# Calinski Harabasz : 13.64951464777411
# size of predicted terms: 900
# Accuracy : 0.3622222222222222
# Precision : 0.4315877908305657
# Recall : 0.3622222222222222
# f1 : 0.3706447921966653
#                       Term               Prediction             Ground truth
# 0        research activity  artificial intelligence  artificial intelligence
# 1          quality dataset                     data                     data
# 2  law enforcement purpose                      law                      law
# 3        pattern detection  artificial intelligence  artificial intelligence
# 4        hardware resource                     data                   market
# 2 iterations:
# ['artificial intelligence', 'ai domain', 'ai system', 'no risk ai system', 'high risk ai system', 'low risk ai system', 'ai system properties', 'ai system development process', 'ai system approach', 'ai system quality measure', 'data', 'personal data', 'anonymous data', 'organization or person', 'provider', 'user', 'affected entity', 'regulator', 'eu country', 'risk', 'data risk', 'poisoning risk', 'system risk', 'terrorist attack risk', 'risk management', 'law', 'regulation', 'right', 'rule', 'requirement', 'obligation', 'law text', 'authority', 'market', 'product', 'service', 'other']
# ['artificial intelligence', 'data', 'organization or person', 'risk', 'law', 'market', 'other']
# unique terms:  900
# cannot links:21
# must links:30
# -0.0051301536
# cluster size :
# |-artificial intelligence : 57
# |-data : 63
# |-organization or person : 35
# |-risk : 82
# |-law : 69
# |-market : 29
# |-other : 601
#   |-unlabeled terms within 'other': 541
# 0.13592453
# cluster size :
# |-artificial intelligence : 115
# |-data : 131
# |-organization or person : 104
# |-risk : 190
# |-law : 142
# |-market : 84
# |-other : 170
#   |-unlabeled terms within 'other': 0
# Silhouette : 0.022592036
# Davies Bouldin : 5.2858774569747204
# Calinski Harabasz : 13.633886872280543
# size of predicted terms: 900
# Accuracy : 0.3788888888888889
# Precision : 0.48058946712005973
# Recall : 0.3788888888888889
# f1 : 0.3978158662274808
#                       Term               Prediction             Ground truth
# 0        research activity  artificial intelligence  artificial intelligence
# 1          quality dataset                     data                     data
# 2  law enforcement purpose                     risk                      law
# 3        pattern detection  artificial intelligence  artificial intelligence
# 4        hardware resource                     data                   market
# 5 iterations:
# ['artificial intelligence', 'ai domain', 'ai system', 'no risk ai system', 'high risk ai system', 'low risk ai system', 'ai system properties', 'ai system development process', 'ai system approach', 'ai system quality measure', 'data', 'personal data', 'anonymous data', 'organization or person', 'provider', 'user', 'affected entity', 'regulator', 'eu country', 'risk', 'data risk', 'poisoning risk', 'system risk', 'terrorist attack risk', 'risk management', 'law', 'regulation', 'right', 'rule', 'requirement', 'obligation', 'law text', 'authority', 'market', 'product', 'service', 'other']
# ['artificial intelligence', 'data', 'organization or person', 'risk', 'law', 'market', 'other']
# unique terms:  900
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7048/3493388070.py in <module>
# ----> 1 df=run_and_store_results(dimensions=10,clusterer="c-dbscan",reducer="umap")
#
# ~\AppData\Local\Temp/ipykernel_7048/420495293.py in run_and_store_results(clusterer, reducer, classifier, iterations, cc_removal, dimensions, min_points, prefix)
#      31         corpus.extract_terms_from_onto()
#      32
# ---> 33         X, y = corpus.get_training_data()
#      34
#      35         model = Model(corpus, min_points=min_points, dimensions=dimensions, clusterer=clusterer, classifier=classifier,reducer=reducer)
#
# E:\OneDrive\NantesCurricula\Intership\Aurelien stage Juillet2023\CO-ISSC\helpers\Corpus.py in get_training_data(self)
#     433
#     434         for term in self.vocabulary :
# --> 435             X.append(self._get_embedding(term))
#     436             y.append(term.get_core_concept())
#     437
#
# E:\OneDrive\NantesCurricula\Intership\Aurelien stage Juillet2023\CO-ISSC\helpers\Corpus.py in _get_embedding(self, term)
#     420             The embedding of the term.
#     421         """
# --> 422         return self.model.encode(term)
#     423
#     424     def get_training_data(self):
#
# ~\AppData\Roaming\Python\Python39\site-packages\sentence_transformers\SentenceTransformer.py in encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     163
#     164             with torch.no_grad():
# --> 165                 out_features = self.forward(features)
#     166
#     167                 if output_value == 'token_embeddings':
#
# ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Roaming\Python\Python39\site-packages\sentence_transformers\models\Transformer.py in forward(self, features)
#      64             trans_features['token_type_ids'] = features['token_type_ids']
#      65
# ---> 66         output_states = self.auto_model(**trans_features, return_dict=False)
#      67         output_tokens = output_states[0]
#      68
#
# ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Roaming\Python\Python39\site-packages\transformers\models\bert\modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1011             past_key_values_length=past_key_values_length,
#    1012         )
# -> 1013         encoder_outputs = self.encoder(
#    1014             embedding_output,
#    1015             attention_mask=extended_attention_mask,
#
# ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Roaming\Python\Python39\site-packages\transformers\models\bert\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     605                 )
#     606             else:
# --> 607                 layer_outputs = layer_module(
#     608                     hidden_states,
#     609                     attention_mask,
#
# ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Roaming\Python\Python39\site-packages\transformers\models\bert\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     495         # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     496         self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 497         self_attention_outputs = self.attention(
#     498             hidden_states,
#     499             attention_mask,
#
# ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Roaming\Python\Python39\site-packages\transformers\models\bert\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     425         output_attentions: Optional[bool] = False,
#     426     ) -> Tuple[torch.Tensor]:
# --> 427         self_outputs = self.self(
#     428             hidden_states,
#     429             attention_mask,
#
# ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Roaming\Python\Python39\site-packages\transformers\models\bert\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     306             value_layer = torch.cat([past_key_value[1], value_layer], dim=2)
#     307         else:
# --> 308             key_layer = self.transpose_for_scores(self.key(hidden_states))
#     309             value_layer = self.transpose_for_scores(self.value(hidden_states))
#     310
#
# ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Roaming\Python\Python39\site-packages\torch\nn\modules\linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2.SVM classifier

# %%
_ = run_and_store_results(classifier="svm",clusterer=None,reducer="none")

# %% [markdown]
# ## 3.ANN classifier

# %%
_ = run_and_store_results(classifier="ann",clusterer=None,reducer="none")

# %% [markdown]
# ## 4. PCA + CDBSCAN

# %%
_ =run_and_store_results(reducer="pca")

# %% [markdown]
# ## 5. none reduction + CDBSCAN

# %%
_=run_and_store_results(reducer="none")

# %% [markdown]
# ## 6. UMAP+DBSCAN
# meaningless, because the number of dbscan cluster is uncontrolllable and not refers to a core concept

# %%
_ = run_and_store_results(clusterer="dbscan",reducer="umap")
# Out:
# 1 iterations:
# ['artificial intelligence', 'ai domain', 'ai system', 'no risk ai system', 'high risk ai system', 'low risk ai system', 'ai system properties', 'ai system development process', 'ai system approach', 'ai system quality measure', 'data', 'personal data', 'anonymous data', 'organization or person', 'provider', 'user', 'affected entity', 'regulator', 'eu country', 'risk', 'data risk', 'poisoning risk', 'system risk', 'terrorist attack risk', 'risk management', 'law', 'regulation', 'right', 'rule', 'requirement', 'obligation', 'law text', 'authority', 'market', 'product', 'service', 'other']
# ['artificial intelligence', 'data', 'organization or person', 'risk', 'law', 'market', 'other']
# unique terms:  900
# cannot links:21
# must links:30
# C:\Users\10258\AppData\Roaming\Python\Python39\site-packages\matplotlib\cbook\__init__.py:1026: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x = np.asanyarray(x)
# cluster size :
# |-artificial intelligence : 707
# |-data : 4
# |-organization or person : 4
# |-risk : 8
# |-law : 17
# |-market : 18
# |-other : 124
#   |-unlabeled terms within 'other': 119
# Silhouette : -0.052198403
# Davies Bouldin : 3.5957827672996654
# Calinski Harabasz : 3.161103676809049
# research activity:0,-1
# trustworthy manner:4,-1
# logs:3,-1
# agreement:4,-1
# compliant product:5,-1
# probabilistic threshold:6,-1
# functioning:5,-1
# water pressure:0,-1
# development team:2,-1
# protocol:0,-1
# special meeting:6,-1
# significant cost:3,-1
# personal assistance:4,-1
# physical rehabilitation:4,-1
# multiple person:2,-1
# accuracy metric:0,-1
# private actor:2,-1
# trade restrictive measure:4,-1
# energy efficiency:0,-1
# potential interest:6,-1
# documentation meeting:6,-1
# independent evaluation:4,-1
# necessary maintenance:4,-1
# operational need:4,-1
# provision:4,-1
# scientific research:0,-1
# physical place:6,-1
# stand-alone basis:0,-1
# information:1,-1
# specific person:2,-1
# humanitarian purpose:6,-1
# eye colour:1,-1
# significant degree:3,-1
# specific interest:6,-1
# specific responsibility:4,-1
# life:6,-1
# private life:4,-1
# accessible format:4,-1
# effective redress:4,-1
# critical entity:3,-1
# task allocation:0,-1
# urgent coordination:4,-1
# validation procedure:4,-1
# appropriate statistical property:0,-1
# high quality training:0,-1
# particular account:6,-1
# single supervisory mechanism:0,-1
# technical robustness:0,-1
# good faith:3,-1
# social control practice:4,-1
# infrastructure management:4,-1
# identity check:0,-1
# credit score:0,-1
# social score :0,-1
# proportionality:4,-1
# action:6,-1
# development process:0,-1
# testing:0,-1
# rapid availability:0,-1
# operation:6,-1
# utmost effort:6,-1
# family life:6,-1
# notification:4,-1
# specific categorie:6,-1
# artificial origin:0,-1
# fictional work:0,-1
# powerful tool:6,-1
# form:6,-1
# contractual relationship:4,-1
# specific logic:0,-1
# surrender procedure:0,-1
# transparency:4,-1
# legitimate commercial practice:5,-1
# duty:4,-1
# development activity:6,-1
# initial phase:6,-1
# machine:6,-1
# board 's task:6,-1
# actor:2,-1
# recommendation:0,-1
# systems incomprehensible:3,-1
# interest:6,-1
# overall machine:0,-1
# european arrest warrant:4,-1
# specific regime:6,-1
# functional setting:6,-1
# real-life setting:0,-1
# human operator:2,-1
# copyright:4,-1
# environmental sustainability:4,-1
# small entreprise:2,-1
# machinery regulation:4,-1
# credit worthiness assessment:0,-1
# guarantee:4,-1
# facial image:1,-1
# research:0,-1
# scientific support:6,-1
# contractual arrangement:4,-1
# individual urgent use case:3,-1
# artificial intelligence regulatory sandboxe :4,-1
# entire spectrum:6,-1
# prudential supervision:4,-1
# personal preference:1,-1
# real world condition:4,-1
# equality body:2,-1
# application problem:3,-1
# advisory task:6,-1
# technical limitation:0,-1
# economic situation:5,-1
# comprehensive form:4,-1
# extreme poverty:3,-1
# financial exclusion:6,-1
# critical infrastructure:3,-1
# official journal:4,-1
# hair colour:1,-1
# substantial modification:0,-1
# supervisory mechanism:6,-1
# value chain:5,-1
# practical pursuit:4,-1
# size of predicted terms: 781
# Accuracy : 0.20486555697823303
# Precision : 0.041969896436001644
# Recall : 0.20486555697823303
# f1 : 0.06966735200109944
#                       Term               Prediction             Ground truth
# 0          quality dataset  artificial intelligence                     data
# 1  law enforcement purpose  artificial intelligence                      law
# 2        pattern detection  artificial intelligence  artificial intelligence
# 3        hardware resource  artificial intelligence                   market
# 4         civilian purpose  artificial intelligence  artificial intelligence
# C:\Users\10258\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Summary:
#    Accuracy  Precision    Recall        F1  Silhouette  Davies Bouldin  \
# 1  0.204866    0.04197  0.204866  0.069667   -0.052198        3.595783
#
#    Calinski Harabasz
# 1           3.161104

# %% [markdown]
# ## 7. UMAP+SVM(with or without bagging)

# %%
_=run_and_store_results(clusterer=None,classifier="svm")
_=run_and_store_results(clusterer=None,classifier="bsvm")

# %% [markdown]
# ## 8. UMAP+ANN

# %%
_=run_and_store_results(clusterer=None,classifier="ann")

# %%
# remove "pseudo anonymous data"
_ = run_and_store_results(clusterer=None,classifier="ann")

# %%
# remove subsub cc
_ = run_and_store_results(clusterer=None,classifier="ann")

# %% [markdown]
# ## 9. Re-balanced

# %%
df3=run_and_store_results(rebalanced=True)

# %% [markdown]
# ## 10. Anything{CC}

# %%
_=run_and_store_results(min_points=4,dimensions=10,prefix="Anything")

# %%
# remove "pseudo anonymous data"
_ = run_and_store_results(min_points=4,dimensions=10,prefix="Anything")

# %%
# remove subsub cc
_ = run_and_store_results(min_points=4,dimensions=10,prefix="Anything")

# %% [markdown]
# ## 11. Anything {CC}

# %%
_=run_and_store_results(min_points=4,dimensions=10,prefix="Anything ")

# %%
# remove "pseudo anonymous data"
_ = run_and_store_results(min_points=4,dimensions=10,prefix="Anything ")

# %% [markdown]
# ## 12. Any{CC}

# %%
_=run_and_store_results(min_points=4,dimensions=10,prefix="Any")

# %%
# remove "pseudo anonymous data"
_ = run_and_store_results(min_points=4,dimensions=10,prefix="Any")

# %% [markdown]
# ## 13. Any {CC}

# %%
_=run_and_store_results(min_points=4,dimensions=10,prefix="Any ")

# %%
# remove "pseudo anonymous data"
_ = run_and_store_results(min_points=4,dimensions=10,prefix="Any ")

# %% [markdown]
# # 14. SMBM

# %%
# remove "pseudo anonymous data"
_ = run_and_store_results(min_points=4,dimensions=10,clusterer="cosine",reducer="none")
